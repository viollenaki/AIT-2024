# %%
class Node:
	def __init__(self):
		self.left = None
		self.right = None
		self.sum = 0
		self.lNode = None
		self.rNode = None
  
class SegmentTree:
    def __init__(self):
        self.root = Node()
