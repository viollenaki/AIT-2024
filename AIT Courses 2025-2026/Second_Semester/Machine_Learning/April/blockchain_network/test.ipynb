# %%
import requests

# %%
response = requests.get("http://192.168.0.182:5001")
print(response.json())
# Out:
# {'endpoints': ['/status', '/chain', '/transactions', '/transactions/<tx_id>/trace', '/mine', '/nodes', '/nodes/register', '/nodes/resolve', '/transactions/relay', '/blocks/relay'], 'name': 'AIT Blockchain Node', 'status': {'chain_length': 1, 'chain_valid': True, 'difficulty': 4, 'latest_hash': 'fd2a762176aaef1504fd0ba4d9df369727ae11182de1ca7f2b8612501ec7c665', 'node_id': 'node-b', 'peers': ['http://192.168.1.10:5000'], 'pending_transactions': 0}}
