# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#    OrderID Customer     Product     Category  Quantity  Price     City  \
# 0        1    Alice      Laptop  Electronics         1    800  Bishkek
# 1        2      Bob       Phone  Electronics         2    500      Osh
# 2        3  Charlie      Tablet  Electronics         1    300  Bishkek
# 3        4    Diana  Headphones  Accessories         3     50  Karakol
# 4        5     Evan    Keyboard  Accessories         2     70      Osh
#
#          Date
# 0  2025-01-05
# 1  2025-01-06
# 2  2025-01-07
# 3  2025-01-07
# 4  2025-01-08

# %%
df.columns
# Out:
# Index(['OrderID', 'Customer', 'Product', 'Category', 'Quantity', 'Price',
#        'City', 'Date'],
#       dtype='object')

# %%
len(df), len(df.columns)
# Out:
# (15, 8)

# %%
def get_mean(df, key):
    print(df[key].mean())
    print(df[key].min())
    print(df[key].max())
get_mean(df,'Quantity')
get_mean(df,'Price')
# Out:
# 2.066666666666667
# 1
# 5
# 337.6666666666667
# 25
# 850

# %%
df["Total Price"] = df['Quantity']*df['Price']

# %%
df['Revenue'] = df['Total Price']

# %%
df
# Out:
#     OrderID Customer     Product     Category  Quantity  Price     City  \
# 0         1    Alice      Laptop  Electronics         1    800  Bishkek
# 1         2      Bob       Phone  Electronics         2    500      Osh
# 2         3  Charlie      Tablet  Electronics         1    300  Bishkek
# 3         4    Diana  Headphones  Accessories         3     50  Karakol
# 4         5     Evan    Keyboard  Accessories         2     70      Osh
# 5         6    Fiona       Mouse  Accessories         5     25  Bishkek
# 6         7   George      Laptop  Electronics         1    850      Osh
# 7         8    Helen       Phone  Electronics         1    520  Karakol
# 8         9      Ian      Tablet  Electronics         2    310  Bishkek
# 9        10     Jane     Monitor  Electronics         1    200      Osh
# 10       11    Kevin       Mouse  Accessories         4     25  Bishkek
# 11       12     Lisa    Keyboard  Accessories         1     70  Karakol
# ...

# %%
df['Total Price'].sum()
# Out:
# 8075

# %%
df['Total Price'].mean()
# Out:
# 538.3333333333334

# %%
df['Total Price'].max()
# Out:
# 1560

# %%
df.groupby('City')['Revenue'].sum().sort_values(ascending=False).head()
# Out:
# City
# Osh        3720
# Bishkek    3615
# Karakol     740
# Name: Revenue, dtype: int64

# %%
df.groupby('Product')['OrderID'].count()
# Out:
# Product
# Headphones    2
# Keyboard      2
# Laptop        3
# Monitor       1
# Mouse         2
# Phone         3
# Tablet        2
# Name: OrderID, dtype: int64

# %%
df.groupby('Customer')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Customer
# Mike       1560
# Nina       1530
# Bob        1000
# George      850
# Alice       800
# Ian         620
# Helen       520
# Charlie     300
# Jane        200
# Diana       150
# Evan        140
# Fiona       125
# Omar        110
# Kevin       100
# Lisa         70
# Name: Revenue, dtype: int64

# %%
df.sort_values(by='Total Price', ascending=False)
# Out:
#     OrderID Customer     Product     Category  Quantity  Price     City  \
# 12       13     Mike      Laptop  Electronics         2    780  Bishkek
# 13       14     Nina       Phone  Electronics         3    510      Osh
# 1         2      Bob       Phone  Electronics         2    500      Osh
# 6         7   George      Laptop  Electronics         1    850      Osh
# 0         1    Alice      Laptop  Electronics         1    800  Bishkek
# 8         9      Ian      Tablet  Electronics         2    310  Bishkek
# 7         8    Helen       Phone  Electronics         1    520  Karakol
# 2         3  Charlie      Tablet  Electronics         1    300  Bishkek
# 9        10     Jane     Monitor  Electronics         1    200      Osh
# 3         4    Diana  Headphones  Accessories         3     50  Karakol
# 4         5     Evan    Keyboard  Accessories         2     70      Osh
# 5         6    Fiona       Mouse  Accessories         5     25  Bishkek
# ...

# %%
mn = df['Price'].mean()
print(mn)
print()
print(sorted(list(df['Price'])))
mn_np=np.std(df['Price'])
print(mn_np)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 mn = df['Price'].mean()
#       2 print(mn)
#       3 print()
#
# NameError: name 'df' is not defined
